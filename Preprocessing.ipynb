# %%
## Driving_Log analysis

# %%
import pandas as pd
# %matplotlib inline

data_frame = pd.read_csv('./driving_log.csv', usecols=[0,1,2,3])

data_frame.describe(include='all')
# Out:
#                                         center  \
# count                                     8036
# unique                                    8036
# top     IMG/center_2016_12_01_13_34_28_811.jpg
# freq                                         1
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#                                          left  \
# count                                    8036
# unique                                   8036
# top      IMG/left_2016_12_01_13_38_33_982.jpg
# freq                                        1
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# ...

# %%
data_frame.hist(column='steering')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028178207278>]], dtype=object)

# %%
#sharp_turn analysis

# %%
data_frame = pd.read_csv('./sharp_turn.csv', usecols=[0,1,2,3])

data_frame.describe(include='all')
# Out:
#                                                center  \
# count                                             738
# unique                                            738
# top     sharp_turn/center_2017_02_10_10_55_10_215.jpg
# freq                                                1
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#                                                 left  \
# count                                            738
# unique                                           738
# top      sharp_turn/left_2017_02_10_10_48_58_707.jpg
# freq                                               1
# ...

# %%
data_frame.hist(column='steering')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002817445B940>]], dtype=object)
